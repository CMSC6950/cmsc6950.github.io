# %% [markdown]
# # Storing Data: Files and HDF5

# %% [markdown]
# Create a subdirectory to store the data files for this lecture.

# %%
# !mkdir -p storing_data

# %% [markdown]
# Create some sample data.

# %%
import numpy as np

# %%
np.random.seed(6950)
A = np.random.randint(0, 1024, size=(50, 50), dtype='uint16')
np.savetxt('storing_data/matrix.txt', A, fmt='%d', delimiter=',')

# %% [markdown]
# ## Files in Python
#
# #### Reading from a text file:

# %%
f = open('storing_data/matrix.txt')
matrix = []
for line in f.readlines():
    row = [int(x) for x in line.split(',')]
    matrix.append(row)
f.close() # Files should always be closed!

# %%
matrix[:3]
# Out:
# [[152,
#   312,
#   1004,
#   578,
#   42,
#   158,
#   528,
#   970,
#   367,
#   783,
#   704,
#   783,
#   288,
#   215,
#   913,
#   873,
#   914,
#   745,
#   282,
#   928,
#   607,
#   745,
#   265,
#   269,
#   981,
#   174,
#   84,
#   688,
#   694,
#   904,
#   567,
#   824,
#   487,
#   736,
#   825,
#   485,
#   188,
#   139,
#   541,
#   523,
#   600,
#   208,
#   449,
#   752,
#   382,
#   665,
#   962,
#   922,
#   184,
#   890],
#  [738,
#   802,
#   444,
#   1022,
#   214,
#   50,
#   820,
#   22,
#   372,
#   531,
#   869,
#   553,
#   616,
#   117,
#   232,
#   1004,
#   549,
#   366,
#   497,
#   448,
#   319,
#   206,
#   912,
#   73,
#   304,
#   816,
#   173,
#   295,
#   739,
#   947,
#   980,
#   635,
#   814,
#   768,
#   980,
#   471,
#   943,
#   720,
#   386,
#   715,
#   976,
#   828,
#   776,
#   962,
#   42,
#   6,
#   583,
#   904,
#   373,
#   561],
#  [156,
#   115,
#   463,
#   551,
#   810,
#   132,
#   83,
#   418,
#   170,
#   736,
#   319,
#   651,
#   205,
#   321,
#   243,
#   643,
#   856,
#   994,
#   724,
#   230,
#   983,
#   592,
#   598,
#   12,
#   1022,
#   721,
#   69,
#   291,
#   930,
#   1009,
#   853,
#   977,
#   819,
#   362,
#   914,
#   741,
#   607,
#   801,
#   995,
#   942,
#   428,
#   226,
#   717,
#   484,
#   492,
#   551,
#   37,
#   151,
#   438,
#   730]]

# %%
A = np.array(matrix)
A
# Out:
# array([[ 152,  312, 1004, ...,  922,  184,  890],
#        [ 738,  802,  444, ...,  904,  373,  561],
#        [ 156,  115,  463, ...,  151,  438,  730],
#        ...,
#        [ 884,  712,  923, ...,  988,  387,  136],
#        [ 610,  967,  917, ...,  227,  383,  482],
#        [ 295,  901,  355, ...,  999,  220,  726]])

# %% [markdown]
# #### Writing to a file:

# %%
f = open('storing_data/matrix_2.txt', 'w')
for row in matrix:
    line = ",".join([ str(x) for x in row ])
    f.write(line + '\n')
f.close()

# %% [markdown]
# #### Useful file modes:
#
#  | Mode | Description                                                    |
#  |:----:| :------------------------------------------------------------- |
#  | 'r'  | Open a file for **reading** (read only).                       |
#  | 'w'  | Open a file for **writing** (current content will be deleted!).|
#  | 'a'  | Open a file for **appending** (writing after current content). |
#  | '+'  | **Update** (open file for both reading and writing).           |

# %% [markdown]
# #### Updating a text file:

# %%
# !cat storing_data/matrix_2.txt
# Out:
# 152,312,1004,578,42,158,528,970,367,783,704,783,288,215,913,873,914,745,282,928,607,745,265,269,981,174,84,688,694,904,567,824,487,736,825,485,188,139,541,523,600,208,449,752,382,665,962,922,184,890
# 738,802,444,1022,214,50,820,22,372,531,869,553,616,117,232,1004,549,366,497,448,319,206,912,73,304,816,173,295,739,947,980,635,814,768,980,471,943,720,386,715,976,828,776,962,42,6,583,904,373,561
# 156,115,463,551,810,132,83,418,170,736,319,651,205,321,243,643,856,994,724,230,983,592,598,12,1022,721,69,291,930,1009,853,977,819,362,914,741,607,801,995,942,428,226,717,484,492,551,37,151,438,730
# 657,148,444,25,731,648,295,890,965,48,758,2,625,682,859,448,427,744,1009,787,608,202,777,440,597,650,309,443,760,123,222,848,693,150,720,410,34,86,123,624,134,320,159,859,254,733,626,599,271,876
# 752,917,925,844,718,530,354,334,723,774,1000,777,438,465,344,377,196,211,159,341,895,425,999,312,251,456,721,140,100,995,447,551,542,518,394,578,442,265,296,552,67,54,1020,747,968,15,221,796,633,921
# 800,142,35,399,243,683,449,468,140,431,750,838,358,196,124,742,586,537,380,128,1007,519,126,691,533,576,1017,337,761,759,607,134,101,686,56,820,488,995,413,183,644,322,317,600,430,275,705,32,196,558
# 993,303,282,559,534,569,158,781,760,892,213,34,819,222,882,271,824,382,317,784,272,928,796,49,122,517,433,438,472,521,739,803,359,501,784,843,799,298,894,533,1010,69,875,757,49,81,226,57,46,552
# 704,982,80,898,505,677,450,484,410,625,358,304,4,555,1017,711,676,533,872,20,632,974,879,175,291,1004,194,495,186,4,20,648,762,932,285,326,789,481,783,588,168,548,734,321,224,988,323,303,898,674
# 29,538,846,605,119,23,149,295,401,420,76,249,399,168,128,143,153,114,303,738,181,524,31,294,1001,732,967,954,935,19,405,746,881,583,880,24,993,536,864,318,504,747,773,550,311,850,872,935,768,335
# 415,345,414,58,167,218,1023,967,745,785,135,540,789,406,287,672,625,967,207,432,35,50,809,837,446,171,494,642,293,101,195,1020,380,385,832,575,754,819,217,841,402,331,1002,371,48,414,471,924,643,679
# 586,170,481,608,944,329,634,238,714,933,412,100,13,796,687,943,167,334,902,280,400,588,211,713,316,917,561,555,244,959,791,558,349,196,445,369,66,309,441,908,140,486,487,64,457,1001,73,574,393,696
# 612,375,166,56,630,965,648,112,578,1004,1015,113,653,790,150,327,771,104,1002,850,48,948,1019,245,928,548,150,277,767,70,770,812,846,345,161,904,308,780,513,977,500,98,422,328,972,821,600,838,136,134
# 572,493,735,160,696,680,255,1023,663,99,263,392,787,752,803,36,548,694,1002,510,266,711,607,175,976,66,444,429,269,265,1000,778,494,27,740,807,129,655,567,274,127,1002,1011,613,11,842,945,848,523,255
# 237,1019,726,45,580,578,237,817,968,202,354,20,240,768,845,718,633,1019,799,463,938,252,178,429,220,416,887,744,689,594,277,651,337,766,448,31,93,244,326,354,337,562,76,324,570,533,802,452,349,365
# 551,973,299,351,348,46,896,912,741,41,136,285,922,918,941,666,546,263,372,962,167,536,111,534,690,584,802,351,704,663,668,356,584,317,612,809,809,55,683,430,851,795,773,854,314,328,796,834,387,483
# 64,553,748,89,561,800,783,986,890,901,626,883,514,285,522,915,960,362,507,419,935,925,337,554,487,816,607,667,103,963,972,234,161,418,269,883,708,682,686,375,661,92,438,374,268,248,876,908,638,228
# 368,274,498,2,1007,760,216,1012,125,563,758,976,775,534,861,486,406,649,324,618,503,902,373,888,126,340,781,504,869,994,151,930,732,364,272,104,355,515,311,438,713,143,550,763,559,958,436,959,716,532
# 833,421,791,569,111,964,797,900,883,651,717,925,155,651,509,1005,420,37,172,915,193,728,417,186,525,37,187,775,657,86,439,944,284,370,446,468,765,161,387,276,85,626,46,600,184,830,380,864,508,293
# 372,851,818,489,234,422,541,80,762,879,757,436,474,631,1010,363,830,88,720,358,914,73,74,146,67,390,990,930,218,167,407,1,509,65,717,359,175,753,984,18,795,115,826,491,268,743,9,235,496,602
# 881,198,60,898,905,368,614,906,828,758,765,47,152,192,681,747,146,557,77,315,806,664,656,776,99,414,893,716,712,420,923,107,590,1015,587,236,324,230,635,539,424,603,825,379,339,127,59,763,761,204
# 162,18,10,114,12,901,221,153,727,171,436,413,560,566,182,429,791,594,227,865,316,429,1001,756,815,999,500,622,964,159,286,593,743,316,971,872,39,938,20,630,926,963,500,696,521,834,307,361,439,759
# 1019,366,278,332,263,370,928,562,958,9,947,864,621,722,923,15,19,683,347,876,617,856,402,233,493,117,545,391,364,956,368,745,314,907,47,974,826,146,473,670,135,339,604,533,32,90,337,59,807,370
# 310,325,398,566,419,641,881,161,256,734,610,765,788,648,551,754,346,213,264,464,748,985,8,767,855,911,788,664,124,46,449,612,828,623,738,673,702,722,510,868,1001,2,63,968,477,392,870,406,607,222
# 42,27,493,425,294,314,393,937,957,49,79,76,397,931,738,137,70,357,1001,763,1021,553,91,172,78,283,499,746,149,769,535,340,510,826,348,903,322,1003,996,164,613,230,670,644,286,67,739,745,407,964
# 29,1015,938,111,954,806,516,121,416,300,288,504,813,483,1009,936,304,998,590,433,906,785,355,2,12,730,146,460,190,542,521,46,336,178,639,112,238,61,999,814,701,44,172,290,449,136,295,669,637,227
# 127,1021,972,1001,399,659,996,351,340,830,686,669,668,192,384,203,780,468,235,141,133,313,463,657,169,87,69,109,688,244,281,296,680,717,0,231,210,170,255,45,369,732,90,367,99,233,515,799,333,945
# 706,757,439,153,694,191,181,108,122,862,722,699,786,499,317,607,966,194,423,897,61,954,374,22,460,498,725,728,10,998,689,366,1021,503,283,867,321,30,93,425,854,856,706,380,76,963,462,217,301,484
# 499,72,298,778,118,381,782,289,709,801,597,215,500,534,177,636,577,698,562,231,95,842,440,249,594,502,492,584,250,691,483,293,6,223,844,894,682,784,332,301,693,337,554,473,44,172,123,390,101,272
# 417,953,266,833,403,478,410,977,298,620,1017,903,172,918,808,17,881,230,787,233,201,941,258,661,320,1001,489,762,400,371,864,982,614,114,22,437,570,175,300,737,383,920,536,126,236,736,802,283,1003,807
# 902,959,843,578,276,968,522,771,107,696,897,195,410,638,99,343,166,96,709,49,140,265,798,881,323,588,233,959,467,553,138,929,16,573,626,386,210,595,623,83,919,216,969,17,283,207,570,416,862,952
# 807,650,26,296,809,461,50,903,297,613,756,1002,191,691,866,952,162,304,849,640,157,152,77,74,831,136,2,87,35,209,830,272,121,971,187,897,635,514,481,672,245,860,433,430,863,431,604,832,420,332
# 507,132,457,86,508,519,233,567,828,976,139,781,394,29,127,633,793,846,814,758,560,395,953,684,221,937,399,948,433,547,646,112,466,316,165,770,155,55,522,686,582,862,933,246,790,400,250,950,312,602
# 497,589,553,370,665,1021,302,468,58,881,791,320,395,140,471,720,419,43,409,202,380,282,169,906,597,986,430,306,488,167,785,506,159,240,539,607,746,42,997,638,937,360,451,270,720,615,263,496,912,494
# 173,822,530,333,944,406,633,224,445,883,766,470,320,678,10,382,292,936,389,214,19,471,705,734,417,504,189,259,726,625,31,48,720,105,431,207,982,45,57,853,355,491,983,200,648,863,527,537,335,694
# 627,203,894,755,973,110,231,610,970,65,796,503,128,365,309,400,629,570,179,208,816,14,484,557,986,60,107,632,1012,575,147,427,306,128,741,460,711,752,960,139,145,815,91,735,800,234,217,930,190,840
# 585,1011,856,102,629,877,699,672,354,123,682,447,974,100,81,309,704,445,926,275,441,681,12,856,762,915,440,819,10,790,901,858,281,402,126,228,850,931,93,433,118,934,225,1008,6,855,659,843,689,64
# 901,221,326,580,633,821,11,344,918,622,821,321,195,9,181,524,941,969,564,706,185,303,238,305,28,920,761,367,634,868,398,355,113,112,964,119,406,327,532,503,896,696,846,308,701,7,672,126,306,796
# 790,819,914,488,796,339,519,190,488,840,791,435,760,530,579,98,30,299,1004,491,437,631,634,199,785,850,46,853,543,326,825,226,394,633,360,308,505,4,575,965,894,41,822,832,243,229,567,706,704,235
# 645,778,311,48,533,6,4,406,203,1009,185,276,995,150,110,423,772,559,1023,917,687,522,180,878,274,284,587,876,511,583,187,121,987,1004,540,967,537,673,661,293,414,284,327,624,271,400,311,359,737,991
# 839,733,156,633,611,98,780,495,219,505,56,925,326,28,196,263,968,264,165,881,63,262,455,23,955,749,79,203,875,496,170,424,633,214,329,845,821,723,860,446,356,172,555,821,877,238,141,712,470,858
# 363,73,618,930,185,159,302,435,541,303,762,640,289,657,395,808,183,334,110,648,316,652,428,15,414,568,332,945,803,192,516,542,783,290,678,21,580,610,962,75,70,293,742,257,237,637,406,887,438,978
# 834,758,212,673,396,637,134,968,768,953,298,396,348,421,460,400,297,271,407,675,704,241,960,586,301,100,187,281,489,807,688,860,421,854,667,64,7,837,579,299,465,839,416,506,973,872,845,577,472,631
# 269,962,987,827,991,378,616,243,920,581,573,216,909,205,104,58,755,391,738,194,96,179,843,60,287,968,965,376,233,894,724,278,483,524,590,249,542,450,347,842,115,853,547,337,56,457,997,100,657,425
# 868,663,615,35,428,756,1001,186,702,265,478,754,89,607,82,222,873,236,492,40,384,652,837,577,482,417,348,965,490,39,104,350,212,702,598,261,325,80,186,790,40,804,703,530,317,628,481,915,791,396
# 158,21,225,830,573,34,913,174,125,29,316,188,778,462,794,861,279,514,398,749,279,747,304,52,763,710,193,330,44,174,788,867,879,605,311,79,884,600,54,813,827,442,106,871,60,573,494,423,886,697
# 347,176,494,237,75,285,387,1014,520,139,153,939,41,149,637,48,648,136,78,329,869,610,18,673,103,656,949,841,257,409,1017,874,457,304,424,490,268,858,481,87,855,469,907,603,15,948,721,523,306,944
# 24,811,134,916,620,133,345,272,331,700,813,295,192,409,374,821,29,505,708,814,683,29,562,821,177,836,310,326,289,545,956,386,721,871,736,888,978,155,35,911,944,619,974,666,344,324,791,302,960,812
# 884,712,923,272,886,682,387,601,836,557,64,404,568,482,184,1003,806,657,155,31,422,746,166,919,872,250,543,882,638,736,878,364,788,1020,858,178,165,992,109,445,622,768,500,129,253,356,570,988,387,136
# 610,967,917,236,848,737,850,733,681,421,441,697,777,171,407,936,939,583,654,1000,905,541,92,33,504,433,762,834,747,972,418,544,805,953,60,590,416,266,701,709,8,57,138,627,959,781,231,227,383,482
# 295,901,355,157,73,818,333,164,70,203,173,428,805,862,577,552,562,64,258,715,620,626,709,449,1006,912,250,117,505,633,673,961,350,502,339,280,236,742,828,658,84,963,863,319,668,453,543,999,220,726

# %%
f = open('storing_data/matrix_2.txt', 'r+')
orig = f.read()
f.seek(0)
f.write('0,0,0,0\n')
f.write(orig)
f.write('1,1,1,1\n')
f.close()

# %%
# !cat storing_data/matrix_2.txt
# Out:
# 0,0,0,0
# 152,312,1004,578,42,158,528,970,367,783,704,783,288,215,913,873,914,745,282,928,607,745,265,269,981,174,84,688,694,904,567,824,487,736,825,485,188,139,541,523,600,208,449,752,382,665,962,922,184,890
# 738,802,444,1022,214,50,820,22,372,531,869,553,616,117,232,1004,549,366,497,448,319,206,912,73,304,816,173,295,739,947,980,635,814,768,980,471,943,720,386,715,976,828,776,962,42,6,583,904,373,561
# 156,115,463,551,810,132,83,418,170,736,319,651,205,321,243,643,856,994,724,230,983,592,598,12,1022,721,69,291,930,1009,853,977,819,362,914,741,607,801,995,942,428,226,717,484,492,551,37,151,438,730
# 657,148,444,25,731,648,295,890,965,48,758,2,625,682,859,448,427,744,1009,787,608,202,777,440,597,650,309,443,760,123,222,848,693,150,720,410,34,86,123,624,134,320,159,859,254,733,626,599,271,876
# 752,917,925,844,718,530,354,334,723,774,1000,777,438,465,344,377,196,211,159,341,895,425,999,312,251,456,721,140,100,995,447,551,542,518,394,578,442,265,296,552,67,54,1020,747,968,15,221,796,633,921
# 800,142,35,399,243,683,449,468,140,431,750,838,358,196,124,742,586,537,380,128,1007,519,126,691,533,576,1017,337,761,759,607,134,101,686,56,820,488,995,413,183,644,322,317,600,430,275,705,32,196,558
# 993,303,282,559,534,569,158,781,760,892,213,34,819,222,882,271,824,382,317,784,272,928,796,49,122,517,433,438,472,521,739,803,359,501,784,843,799,298,894,533,1010,69,875,757,49,81,226,57,46,552
# 704,982,80,898,505,677,450,484,410,625,358,304,4,555,1017,711,676,533,872,20,632,974,879,175,291,1004,194,495,186,4,20,648,762,932,285,326,789,481,783,588,168,548,734,321,224,988,323,303,898,674
# 29,538,846,605,119,23,149,295,401,420,76,249,399,168,128,143,153,114,303,738,181,524,31,294,1001,732,967,954,935,19,405,746,881,583,880,24,993,536,864,318,504,747,773,550,311,850,872,935,768,335
# 415,345,414,58,167,218,1023,967,745,785,135,540,789,406,287,672,625,967,207,432,35,50,809,837,446,171,494,642,293,101,195,1020,380,385,832,575,754,819,217,841,402,331,1002,371,48,414,471,924,643,679
# 586,170,481,608,944,329,634,238,714,933,412,100,13,796,687,943,167,334,902,280,400,588,211,713,316,917,561,555,244,959,791,558,349,196,445,369,66,309,441,908,140,486,487,64,457,1001,73,574,393,696
# 612,375,166,56,630,965,648,112,578,1004,1015,113,653,790,150,327,771,104,1002,850,48,948,1019,245,928,548,150,277,767,70,770,812,846,345,161,904,308,780,513,977,500,98,422,328,972,821,600,838,136,134
# 572,493,735,160,696,680,255,1023,663,99,263,392,787,752,803,36,548,694,1002,510,266,711,607,175,976,66,444,429,269,265,1000,778,494,27,740,807,129,655,567,274,127,1002,1011,613,11,842,945,848,523,255
# 237,1019,726,45,580,578,237,817,968,202,354,20,240,768,845,718,633,1019,799,463,938,252,178,429,220,416,887,744,689,594,277,651,337,766,448,31,93,244,326,354,337,562,76,324,570,533,802,452,349,365
# 551,973,299,351,348,46,896,912,741,41,136,285,922,918,941,666,546,263,372,962,167,536,111,534,690,584,802,351,704,663,668,356,584,317,612,809,809,55,683,430,851,795,773,854,314,328,796,834,387,483
# 64,553,748,89,561,800,783,986,890,901,626,883,514,285,522,915,960,362,507,419,935,925,337,554,487,816,607,667,103,963,972,234,161,418,269,883,708,682,686,375,661,92,438,374,268,248,876,908,638,228
# 368,274,498,2,1007,760,216,1012,125,563,758,976,775,534,861,486,406,649,324,618,503,902,373,888,126,340,781,504,869,994,151,930,732,364,272,104,355,515,311,438,713,143,550,763,559,958,436,959,716,532
# 833,421,791,569,111,964,797,900,883,651,717,925,155,651,509,1005,420,37,172,915,193,728,417,186,525,37,187,775,657,86,439,944,284,370,446,468,765,161,387,276,85,626,46,600,184,830,380,864,508,293
# 372,851,818,489,234,422,541,80,762,879,757,436,474,631,1010,363,830,88,720,358,914,73,74,146,67,390,990,930,218,167,407,1,509,65,717,359,175,753,984,18,795,115,826,491,268,743,9,235,496,602
# 881,198,60,898,905,368,614,906,828,758,765,47,152,192,681,747,146,557,77,315,806,664,656,776,99,414,893,716,712,420,923,107,590,1015,587,236,324,230,635,539,424,603,825,379,339,127,59,763,761,204
# 162,18,10,114,12,901,221,153,727,171,436,413,560,566,182,429,791,594,227,865,316,429,1001,756,815,999,500,622,964,159,286,593,743,316,971,872,39,938,20,630,926,963,500,696,521,834,307,361,439,759
# 1019,366,278,332,263,370,928,562,958,9,947,864,621,722,923,15,19,683,347,876,617,856,402,233,493,117,545,391,364,956,368,745,314,907,47,974,826,146,473,670,135,339,604,533,32,90,337,59,807,370
# 310,325,398,566,419,641,881,161,256,734,610,765,788,648,551,754,346,213,264,464,748,985,8,767,855,911,788,664,124,46,449,612,828,623,738,673,702,722,510,868,1001,2,63,968,477,392,870,406,607,222
# 42,27,493,425,294,314,393,937,957,49,79,76,397,931,738,137,70,357,1001,763,1021,553,91,172,78,283,499,746,149,769,535,340,510,826,348,903,322,1003,996,164,613,230,670,644,286,67,739,745,407,964
# 29,1015,938,111,954,806,516,121,416,300,288,504,813,483,1009,936,304,998,590,433,906,785,355,2,12,730,146,460,190,542,521,46,336,178,639,112,238,61,999,814,701,44,172,290,449,136,295,669,637,227
# 127,1021,972,1001,399,659,996,351,340,830,686,669,668,192,384,203,780,468,235,141,133,313,463,657,169,87,69,109,688,244,281,296,680,717,0,231,210,170,255,45,369,732,90,367,99,233,515,799,333,945
# 706,757,439,153,694,191,181,108,122,862,722,699,786,499,317,607,966,194,423,897,61,954,374,22,460,498,725,728,10,998,689,366,1021,503,283,867,321,30,93,425,854,856,706,380,76,963,462,217,301,484
# 499,72,298,778,118,381,782,289,709,801,597,215,500,534,177,636,577,698,562,231,95,842,440,249,594,502,492,584,250,691,483,293,6,223,844,894,682,784,332,301,693,337,554,473,44,172,123,390,101,272
# 417,953,266,833,403,478,410,977,298,620,1017,903,172,918,808,17,881,230,787,233,201,941,258,661,320,1001,489,762,400,371,864,982,614,114,22,437,570,175,300,737,383,920,536,126,236,736,802,283,1003,807
# 902,959,843,578,276,968,522,771,107,696,897,195,410,638,99,343,166,96,709,49,140,265,798,881,323,588,233,959,467,553,138,929,16,573,626,386,210,595,623,83,919,216,969,17,283,207,570,416,862,952
# 807,650,26,296,809,461,50,903,297,613,756,1002,191,691,866,952,162,304,849,640,157,152,77,74,831,136,2,87,35,209,830,272,121,971,187,897,635,514,481,672,245,860,433,430,863,431,604,832,420,332
# 507,132,457,86,508,519,233,567,828,976,139,781,394,29,127,633,793,846,814,758,560,395,953,684,221,937,399,948,433,547,646,112,466,316,165,770,155,55,522,686,582,862,933,246,790,400,250,950,312,602
# 497,589,553,370,665,1021,302,468,58,881,791,320,395,140,471,720,419,43,409,202,380,282,169,906,597,986,430,306,488,167,785,506,159,240,539,607,746,42,997,638,937,360,451,270,720,615,263,496,912,494
# 173,822,530,333,944,406,633,224,445,883,766,470,320,678,10,382,292,936,389,214,19,471,705,734,417,504,189,259,726,625,31,48,720,105,431,207,982,45,57,853,355,491,983,200,648,863,527,537,335,694
# 627,203,894,755,973,110,231,610,970,65,796,503,128,365,309,400,629,570,179,208,816,14,484,557,986,60,107,632,1012,575,147,427,306,128,741,460,711,752,960,139,145,815,91,735,800,234,217,930,190,840
# 585,1011,856,102,629,877,699,672,354,123,682,447,974,100,81,309,704,445,926,275,441,681,12,856,762,915,440,819,10,790,901,858,281,402,126,228,850,931,93,433,118,934,225,1008,6,855,659,843,689,64
# 901,221,326,580,633,821,11,344,918,622,821,321,195,9,181,524,941,969,564,706,185,303,238,305,28,920,761,367,634,868,398,355,113,112,964,119,406,327,532,503,896,696,846,308,701,7,672,126,306,796
# 790,819,914,488,796,339,519,190,488,840,791,435,760,530,579,98,30,299,1004,491,437,631,634,199,785,850,46,853,543,326,825,226,394,633,360,308,505,4,575,965,894,41,822,832,243,229,567,706,704,235
# 645,778,311,48,533,6,4,406,203,1009,185,276,995,150,110,423,772,559,1023,917,687,522,180,878,274,284,587,876,511,583,187,121,987,1004,540,967,537,673,661,293,414,284,327,624,271,400,311,359,737,991
# 839,733,156,633,611,98,780,495,219,505,56,925,326,28,196,263,968,264,165,881,63,262,455,23,955,749,79,203,875,496,170,424,633,214,329,845,821,723,860,446,356,172,555,821,877,238,141,712,470,858
# 363,73,618,930,185,159,302,435,541,303,762,640,289,657,395,808,183,334,110,648,316,652,428,15,414,568,332,945,803,192,516,542,783,290,678,21,580,610,962,75,70,293,742,257,237,637,406,887,438,978
# 834,758,212,673,396,637,134,968,768,953,298,396,348,421,460,400,297,271,407,675,704,241,960,586,301,100,187,281,489,807,688,860,421,854,667,64,7,837,579,299,465,839,416,506,973,872,845,577,472,631
# 269,962,987,827,991,378,616,243,920,581,573,216,909,205,104,58,755,391,738,194,96,179,843,60,287,968,965,376,233,894,724,278,483,524,590,249,542,450,347,842,115,853,547,337,56,457,997,100,657,425
# 868,663,615,35,428,756,1001,186,702,265,478,754,89,607,82,222,873,236,492,40,384,652,837,577,482,417,348,965,490,39,104,350,212,702,598,261,325,80,186,790,40,804,703,530,317,628,481,915,791,396
# 158,21,225,830,573,34,913,174,125,29,316,188,778,462,794,861,279,514,398,749,279,747,304,52,763,710,193,330,44,174,788,867,879,605,311,79,884,600,54,813,827,442,106,871,60,573,494,423,886,697
# 347,176,494,237,75,285,387,1014,520,139,153,939,41,149,637,48,648,136,78,329,869,610,18,673,103,656,949,841,257,409,1017,874,457,304,424,490,268,858,481,87,855,469,907,603,15,948,721,523,306,944
# 24,811,134,916,620,133,345,272,331,700,813,295,192,409,374,821,29,505,708,814,683,29,562,821,177,836,310,326,289,545,956,386,721,871,736,888,978,155,35,911,944,619,974,666,344,324,791,302,960,812
# 884,712,923,272,886,682,387,601,836,557,64,404,568,482,184,1003,806,657,155,31,422,746,166,919,872,250,543,882,638,736,878,364,788,1020,858,178,165,992,109,445,622,768,500,129,253,356,570,988,387,136
# 610,967,917,236,848,737,850,733,681,421,441,697,777,171,407,936,939,583,654,1000,905,541,92,33,504,433,762,834,747,972,418,544,805,953,60,590,416,266,701,709,8,57,138,627,959,781,231,227,383,482
# 295,901,355,157,73,818,333,164,70,203,173,428,805,862,577,552,562,64,258,715,620,626,709,449,1006,912,250,117,505,633,673,961,350,502,339,280,236,742,828,658,84,963,863,319,668,453,543,999,220,726
# 1,1,1,1

# %% [markdown]
# #### The `with` statement (context manager)

# %%
matrix = []
with open('storing_data/matrix.txt') as f:
    for line in f.readlines():
        row = [int(x) for x in line.split(',')]
        matrix.append(row)
A = np.array(matrix, dtype='uint16')
A
# Out:
# array([[ 152,  312, 1004, ...,  922,  184,  890],
#        [ 738,  802,  444, ...,  904,  373,  561],
#        [ 156,  115,  463, ...,  151,  438,  730],
#        ...,
#        [ 884,  712,  923, ...,  988,  387,  136],
#        [ 610,  967,  917, ...,  227,  383,  482],
#        [ 295,  901,  355, ...,  999,  220,  726]], dtype=uint16)

# %% [markdown]
# **This will automatically close the file when leaving the `with` block**

# %% [markdown]
# NumPy has the ability to save arrays as text files

# %%
np.savetxt('storing_data/matrix_3.txt', A)
np.savetxt('storing_data/matrix_4.txt', A, fmt='%d')

# %%
# !head -1 storing_data/matrix_3.txt
# Out:
# 1.520000000000000000e+02 3.120000000000000000e+02 1.004000000000000000e+03 5.780000000000000000e+02 4.200000000000000000e+01 1.580000000000000000e+02 5.280000000000000000e+02 9.700000000000000000e+02 3.670000000000000000e+02 7.830000000000000000e+02 7.040000000000000000e+02 7.830000000000000000e+02 2.880000000000000000e+02 2.150000000000000000e+02 9.130000000000000000e+02 8.730000000000000000e+02 9.140000000000000000e+02 7.450000000000000000e+02 2.820000000000000000e+02 9.280000000000000000e+02 6.070000000000000000e+02 7.450000000000000000e+02 2.650000000000000000e+02 2.690000000000000000e+02 9.810000000000000000e+02 1.740000000000000000e+02 8.400000000000000000e+01 6.880000000000000000e+02 6.940000000000000000e+02 9.040000000000000000e+02 5.670000000000000000e+02 8.240000000000000000e+02 4.870000000000000000e+02 7.360000000000000000e+02 8.250000000000000000e+02 4.850000000000000000e+02 1.880000000000000000e+02 1.390000000000000000e+02 5.410000000000000000e+02 5.230000000000000000e+02 6.000000000000000000e+02 2.080000000000000000e+02 4.490000000000000000e+02 7.520000000000000000e+02 3.820000000000000000e+02 6.650000000000000000e+02 9.620000000000000000e+02 9.220000000000000000e+02 1.840000000000000000e+02 8.900000000000000000e+02

# %%
# !head -1 storing_data/matrix_4.txt
# Out:
# 152 312 1004 578 42 158 528 970 367 783 704 783 288 215 913 873 914 745 282 928 607 745 265 269 981 174 84 688 694 904 567 824 487 736 825 485 188 139 541 523 600 208 449 752 382 665 962 922 184 890

# %% [markdown]
# and also as binary files:

# %%
np.save('storing_data/matrix_5.npy', A, )

# %%
np.savez('storing_data/matrix_6.npz', A, ) # compressed with gzip

# %%
# !ls -l storing_data
# Out:
# total 416
# -rw-r--r--  1 jmunroe  staff   5128 24 May 12:06 matrix.npy
# -rw-r--r--  1 jmunroe  staff   9804 24 May 12:01 matrix.txt
# -rw-r--r--  1 jmunroe  staff  62500 24 May 12:05 matrix3.txt
# -rw-r--r--  1 jmunroe  staff   9804 24 May 12:05 matrix4.txt
# -rw-r--r--  1 jmunroe  staff   9820 24 May 12:02 matrix_2.txt
# -rw-r--r--  1 jmunroe  staff  62500 24 May 12:06 matrix_3.txt
# -rw-r--r--  1 jmunroe  staff   9804 24 May 12:06 matrix_4.txt
# -rw-r--r--  1 jmunroe  staff   5128 24 May 12:07 matrix_5.npy
# -rw-r--r--  1 jmunroe  staff   5244 24 May 12:07 matrix_5.npz
# -rw-r--r--  1 jmunroe  staff   5244 24 May 12:07 matrix_6.npz

# %% [markdown]
# ## HDF5 files (Hierachrical Data Format)
#
# The package PyTables is used in this section.
#
# * PyTables User Guide: <http://www.pytables.org/usersguide/>

# %%
import os
import numpy as np
if os.path.isfile('ch10.h5'):
    os.remove('ch10.h5')

# %%
import tables as tb
f = tb.open_file('ch10.h5', 'a')

# %% [markdown]
# ( If the above import command failed, you need to install PyTables first.
# If you are using conda, the required command is `conda install pytables` )

# %% [markdown]
# Create a group on the root node with the name `a_group` with the title "My Group" :

# %%
f.create_group('/', 'a_group', "My Group")
f.root.a_group
# Out:
# /a_group (Group) 'My Group'
#   children := []

# %% [markdown]
# In PyTables, arrays are of fixed size. They have to be created with data.
# Tables need to have the same datetype (like in NumPy) and have variable length.

# %%
# integer array
f.create_array('/a_group', 'arthur_count', np.array([1, 2, 5, 3]))

# tables need descriptions
dt = np.dtype([('id', int), ('name', 'S10')])
knights = np.array([(42, 'Lancelot'), (12, 'Bedivere')], dtype=dt)
f.create_table('/', 'knights', dt)
f.root.knights.append(knights)

# %% [markdown]
# The hierarchy now looks like:
#
# ```
# /
# |-- a_group/
# |   |-- arthur_count
# |
# |-- knights
# ```

# %%
f.root.a_group.arthur_count[:]
# Out:
# array([1, 2, 5, 3])

# %%
type(f.root.a_group.arthur_count[:])
# Out:
# numpy.ndarray

# %%
type(f.root.a_group.arthur_count)
# Out:
# tables.array.Array

# %%
f.root.knights[1]
# Out:
# (12, b'Bedivere')

# %%
f.root.knights[:1]
# Out:
# array([(42, b'Lancelot')], dtype=[('id', '<i8'), ('name', 'S10')])

# %%
mask = (f.root.knights.cols.id[:] < 28)
f.root.knights[mask]
# Out:
# array([(12, b'Bedivere')], dtype=[('id', '<i8'), ('name', 'S10')])

# %%
f.root.knights[([1, 0],)]
# Out:
# array([(12, b'Bedivere'), (42, b'Lancelot')],
#       dtype=[('id', '<i8'), ('name', 'S10')])

# %%
# don't forget to close the file
f.close()

# %% [markdown]
# ## Hierachry Layout

# %% [markdown]
# ##  In-Core and Out-of-Core operations
#
# ### In-Core operations
#
# ```python
# a = np.array(...)
# b = np.array(...)
# c = 42 * a + 28 * b + 6
# ```
#
# is equivalent to :
#
# ```python
# temp1 = 42 * a
# temp2 = 28 * b
# temp3 = temp1 + temp2
# c = temp3 + 6
# ```
# This can exhaust memory if the arrays are very large.
#
# Alternatively it could be implemented element-wise as:
#
# ```python
# c = np.empty(...)
# for i in range(len(c)):
#     c[i] = 42 * a[i] + 28 * b[i] + 6
# ```
#
# This version needs less memory, but can be extremely slow if each dataset needs to be read from disk one by one.

# %% [markdown]
# ### Out-of-Core operations
#
# A better strategy is to use a hybrid, loading reasonable sized chunks of several elements into memory an performing the operations on all elements in the chunk, before processing the next chunk.
#
# In Python the `numexpr` library provides a way to perform chunked, element-wise computations on NumPy arrays.  PyTables offers the `tb.Expr` class to do just that.

# %%
# clean-up
if os.path.isfile('ch10-1.h5'):
    os.remove('ch10-1.h5')

# open a new file
shape = (10, 10000)
f = tb.open_file('ch10-1.h5', "w")

# create the arrays 
a = f.create_carray(f.root, 'a', tb.Float32Atom(dflt=1.), shape)
b = f.create_carray(f.root, 'b', tb.Float32Atom(dflt=2.), shape)
c = f.create_carray(f.root, 'c', tb.Float32Atom(dflt=3.), shape)

# %%
f
# Out:
# File(filename=ch10-1.h5, title='', mode='w', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /a (CArray(10, 10000)) ''
#   atom := Float32Atom(shape=(), dflt=1.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (1, 10000)
# /b (CArray(10, 10000)) ''
#   atom := Float32Atom(shape=(), dflt=2.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (1, 10000)
# /c (CArray(10, 10000)) ''
#   atom := Float32Atom(shape=(), dflt=3.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (1, 10000)

# %%
# evaluate the expression, using the c array as the output
expr = tb.Expr("42*a + 28*b + 6")
expr.set_output(c)
expr.eval()
# Out:
# /c (CArray(10, 10000)) ''
#   atom := Float32Atom(shape=(), dflt=3.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (1, 10000)

# %%
# close the file
f.close()

# %% [markdown]
# ## Querying
#
#
#
# ```python
# for row in tab.where('(col1 < 42) and col2 == col3'):
#     #do something with row
# ```

# %%
# prepare some random data
n = 1000
data = np.random.randint(0, 100, size=(n, 3))

# and create some hits for our query
for i in np.random.randint(0, n, n//20):
    data[i,2] = data[i,1]

# %%
# cleanup:
if os.path.exists('ch10-3.h5'):
    os.remove('ch10-3.h5')

# Datatype / table headers
dt = np.dtype([
        ('col1', int),
        ('col2', int),
        ('col3', int),
])

# create a table all_data in a file:
f = tb.open_file('ch10-3.h5', 'a')
tab = f.create_table('/', 'all_data', dt)
tab.append(data)

# %% [markdown]
# **`tb.Table.where(condition)`** returns an iterator of matches:

# %%
for row in tab.where('(col1 < 42) & (col2 == col3)'):
    # do something with data in row
    print (row[:])
# Out:
# (35, 9, 9)
# (4, 79, 79)
# (23, 29, 29)
# (35, 13, 13)
# (1, 62, 62)
# (22, 4, 4)
# (0, 10, 10)
# (0, 98, 98)
# (27, 86, 86)
# (38, 38, 38)
# (16, 10, 10)
# (6, 44, 44)
# (26, 35, 35)
# (15, 19, 19)
# (20, 34, 34)
# (14, 92, 92)
# (13, 62, 62)
# (38, 81, 81)
# (3, 41, 41)
# (1, 96, 96)
# (38, 31, 31)
# (3, 50, 50)

# %% [markdown]
# **`tb.Table.get_where_list(condition)`** returns a list of indices:

# %%
# get list of indices
tab.get_where_list('(col1 < 42) & (col2 == col3)')
# Out:
# array([  2,  18,  48,  67, 159, 193, 251, 341, 375, 393, 416, 469, 515,
#        572, 589, 632, 654, 693, 772, 832, 849, 903])

# %% [markdown]
# **`tb.Table.read_where(condition)`** returns a list of results:

# %%
tab.read_where('(col1 < 42) & (col2 == col3)')
# Out:
# array([(35,  9,  9), ( 4, 79, 79), (23, 29, 29), (35, 13, 13),
#        ( 1, 62, 62), (22,  4,  4), ( 0, 10, 10), ( 0, 98, 98),
#        (27, 86, 86), (38, 38, 38), (16, 10, 10), ( 6, 44, 44),
#        (26, 35, 35), (15, 19, 19), (20, 34, 34), (14, 92, 92),
#        (13, 62, 62), (38, 81, 81), ( 3, 41, 41), ( 1, 96, 96),
#        (38, 31, 31), ( 3, 50, 50)],
#       dtype=[('col1', '<i8'), ('col2', '<i8'), ('col3', '<i8')])

# %% [markdown]
# **`tb.Table.append_where(destination, condition)`** appends results to a different table:

# %%
tab2 = f.create_table('/', 'some_data', dt)
tab.append_where(tab2 , '(col1 < 42) & (col2 == col3)')
# Out:
# 22

# %%
# close the file
f.close()

# %% [markdown]
# ## HDF5 utilities
#
# **h5ls** - list content of HDF5 files:

# %%
# !h5ls ch10-3.h5
# Out:
# all_data                 Dataset {1000/Inf}
# some_data                Dataset {22/Inf}

# %% [markdown]
# **h5dump** - print content of an HDF5 table:

# %%
# !h5dump -d "/some_data" ch10-3.h5
# Out:
# HDF5 "ch10-3.h5" {
# DATASET "/some_data" {
#    DATATYPE  H5T_COMPOUND {
#       H5T_STD_I64LE "col1";
#       H5T_STD_I64LE "col2";
#       H5T_STD_I64LE "col3";
#    }
#    DATASPACE  SIMPLE { ( 22 ) / ( H5S_UNLIMITED ) }
#    DATA {
#    (0): {
#          35,
#          9,
#          9
#       },
#    (1): {
#          4,
#          79,
#          79
#       },
#    (2): {
#          23,
#          29,
#          29
#       },
#    (3): {
#          35,
#          13,
#          13
#       },
#    (4): {
#          1,
#          62,
#          62
#       },
#    (5): {
#          22,
#          4,
#          4
#       },
#    (6): {
#          0,
#          10,
#          10
#       },
#    (7): {
#          0,
#          98,
#          98
#       },
#    (8): {
#          27,
#          86,
#          86
#       },
#    (9): {
#          38,
#          38,
#          38
#       },
#    (10): {
#          16,
#          10,
#          10
#       },
#    (11): {
#          6,
#          44,
#          44
#       },
#    (12): {
#          26,
#          35,
#          35
#       },
#    (13): {
#          15,
#          19,
#          19
#       },
#    (14): {
#          20,
#          34,
#          34
#       },
#    (15): {
#          14,
#          92,
#          92
#       },
#    (16): {
#          13,
#          62,
#          62
#       },
#    (17): {
#          38,
#          81,
#          81
#       },
#    (18): {
#          3,
#          41,
#          41
#       },
#    (19): {
#          1,
#          96,
#          96
#       },
#    (20): {
#          38,
#          31,
#          31
#       },
#    (21): {
#          3,
#          50,
#          50
#       }
#    }
#    ATTRIBUTE "CLASS" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 5;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  SCALAR
#       DATA {
#       (0): "TABLE"
#       }
#    }
#    ATTRIBUTE "FIELD_0_FILL" {
#       DATATYPE  H5T_STD_I64LE
#       DATASPACE  SCALAR
#       DATA {
#       (0): 0
#       }
#    }
#    ATTRIBUTE "FIELD_0_NAME" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 4;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  SCALAR
#       DATA {
#       (0): "col1"
#       }
#    }
#    ATTRIBUTE "FIELD_1_FILL" {
#       DATATYPE  H5T_STD_I64LE
#       DATASPACE  SCALAR
#       DATA {
#       (0): 0
#       }
#    }
#    ATTRIBUTE "FIELD_1_NAME" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 4;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  SCALAR
#       DATA {
#       (0): "col2"
#       }
#    }
#    ATTRIBUTE "FIELD_2_FILL" {
#       DATATYPE  H5T_STD_I64LE
#       DATASPACE  SCALAR
#       DATA {
#       (0): 0
#       }
#    }
#    ATTRIBUTE "FIELD_2_NAME" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 4;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  SCALAR
#       DATA {
#       (0): "col3"
#       }
#    }
#    ATTRIBUTE "NROWS" {
#       DATATYPE  H5T_STD_I64LE
#       DATASPACE  SCALAR
#       DATA {
#       (0): 22
#       }
#    }
#    ATTRIBUTE "TITLE" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 1;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  NULL
#       DATA {
#       }
#    }
#    ATTRIBUTE "VERSION" {
#       DATATYPE  H5T_STRING {
#          STRSIZE 3;
#          STRPAD H5T_STR_NULLTERM;
#          CSET H5T_CSET_UTF8;
#          CTYPE H5T_C_S1;
#       }
#       DATASPACE  SCALAR
#       DATA {
#       (0): "2.7"
#       }
#    }
# }
# }
